# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv", sep = "\t")

# %%
df.drop(columns=["Subcategory"], inplace = True)

# %%
df
# Out:
#      uid     Category Metal Purity  Weight                Image
# 0    S01          Set  gold    18k     NaN  images/SET/set1.png
# 1    S02          Set  gold    18k     NaN  images/SET/set2.png
# 2    S03          Set  gold    18k     NaN  images/SET/set3.png
# 3    S04          Set  gold    18k     NaN  images/SET/set4.png
# 4    S05          Set  gold    18k     NaN  images/SET/set5.png
# 5    S06          Set  gold    18k     NaN  images/SET/set6.png
# 6    E01     Earring   gold    18k     NaN     images/ER/E1.png
# 7    E02     Earring   gold    18k     NaN     images/ER/E2.png
# 8    E03     Earring   gold    18k     NaN     images/ER/E3.png
# 9    E04     Earring   gold    18k     NaN     images/ER/E4.png
# 10   E05     Earring   gold    18k     NaN     images/ER/E5.png
# 11   E06     Earring   gold    18k     NaN     images/ER/E6.png
# 12   E07     Earring   gold    18k     NaN     images/ER/E7.png
# 13  MS01  Mangalsutra  gold    18k     NaN   images/MS/ms01.png
# 14  MS02  Mangalsutra  gold    18k     NaN   images/MS/ms02.png
# 15  MS03  Mangalsutra  gold    18K     NaN   images/MS/ms03.png
# 16  MS04  Mangalsutra  gold    18k     NaN   images/MS/ms04.png
# 17  BR01     Bracelet  gold    18k     NaN    images/BR/B01.png
# 18  BR02     Bracelet  gold    18k     NaN    images/BR/B02.png
# 19  BR03     Bracelet  gold    18k     NaN    images/BR/B03.png
# 20  BG01       Bangle  gold    18k     NaN   images/BG/BG01.png
# 21  BG02       Bangle  gold    18k     NaN   images/BG/BG02.png
# 22  BG03       Bangle  gold    18k     NaN   images/BG/BG03.png
# 23  BG04       Bangle  gold    18k     NaN   images/BG/BG04.png
# 24  BG05       Bangle  gold    18k     NaN   images/BG/BG05.png
# 25  BG06       Bangle  gold    18k     NaN   images/BG/BG06.png
# 26  BG07       Bangle  gold    18k     NaN   images/BG/BG07.png
# 27  TK01         Tika  gold    18k     NaN   images/TK/TK01.png
# 28   P01      Pendant  gold    18k     NaN    images/PD/P01.png

# %%
df.to_csv("data_cleaned.csv", index = False)
